# %% [markdown]
# ## Training

# %%
import numpy as np
import pandas as pd
import pickle
from collections import namedtuple
from IPython.display import display, HTML
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import RFECV
from sklearn.metrics import r2_score,make_scorer
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt
from collections import Counter ,OrderedDict
from itertools import compress
# %matplotlib inline

# %%
Dataset=namedtuple('Dataset','exchange df')
DatasetMLModel= namedtuple('DatasetMLModel','exchange df train_size tscv_split test_size')
Regressor= namedtuple('Regressor','name regressor_class params type')
FeatureSelection= namedtuple('FeatureSelection','dataset regressor params RFECV')

# %%
with open('datasets/set_of_datasets.pkl', 'rb') as input1:
    set_of_datasets = pickle.load(input1)
with open('datasets/fs_results.pkl', 'rb') as input2:
    fs_results = pickle.load(input2)

# %%
regressors={
    'LinearRegression': Regressor('LinearRegression', LinearRegression, None,'linear_model'), 
    'Lasso':Regressor('Lasso', Lasso, None,'linear_model'),
#Error it is for categorical features    'LogisticRegression':Regressor('LogisticRegression', LogisticRegression, None,'linear_model'),
    'DecisionTreeRegressor':Regressor('DecisionTreeRegressor', DecisionTreeRegressor, None,'tree'),
    'GradientBoostingRegressor':Regressor('GradientBoostingRegressor', GradientBoostingRegressor, None,'ensemble')
}
regressors_plus={
#     'Ridge':Regressor('Ridge', Ridge, None,'linear_model'),
    'SVR':Regressor('SVR', SVR, None,'svm'),
    'KernelRidge':Regressor('KernelRidge', KernelRidge, None,'svm'),
}
parameters_per_regressor={
    'LinearRegression':{},
    'Lasso': { 'alpha':[100,100,1000,10000]},
    'SVR': {'C': [1,10,100,1000,10000], 'gamma': [0.01, 0.1,1 ,10,100], 'kernel': ['rbf', 'sigmoid', 'poly']},
    'KernelRidge': { 'alpha':[1,10,100,100],'gamma': [0.01, 0.1,1 ,10,100],'kernel': ['rbf', 'sigmoid', 'poly']},
    'DecisionTreeRegressor': {'max_depth':range(1,15),'criterion':['mse','friedman_mse']},
    'GradientBoostingRegressor':{}
}

# %%
# TODO: Import 'make_scorer', 'DecisionTreeRegressor', and 'GridSearchCV'
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

def make_X_Y(dataset, features=['close'],target=['close_Target']):
    X=dataset.df[features]
    y=dataset.df[target]
    return X,y

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    

    score = r2_score(y_true,y_predict)
    
    # Return the score
    return score

# %%
def fit_all(regressors,parameters_per_regressor,fs_results,set_of_datasets):
    columns=['Currency Pair','Regressor','Target','Dataset','Score','Features','BestEstimator']
    data=[]
    scoring_fnc = make_scorer(performance_metric)
    for dataset_key, fs_scores, target in fs_results:
        set_data=set_of_datasets[dataset_key]
        for index, row in fs_scores.iterrows():
            (currency_pair,regressor_key)=index
            dataset=set_data[currency_pair]
            features=row['features']
            X , y = make_X_Y(dataset,features,target)
            reg=regressors[regressor_key].regressor_class()
            parameters=parameters_per_regressor[regressor_key]
            cvts=TimeSeriesSplit(n_splits=dataset.tscv_split)
            print(  currency_pair,
                    regressor_key,
                    target,
                    dataset_key,)
            grid = GridSearchCV(reg, parameters,scoring_fnc, cv=cvts) 
            grid = grid.fit(X, y)
            data_row=[
                currency_pair,
                regressor_key,
                target,
                dataset_key,
                grid.best_score_,
                features,
                grid.best_estimator_
            ]
            data.append(data_row)
            for regressor_key, regressor  in regressors_plus.items():
                reg=regressor.regressor_class()
                parameters=parameters_per_regressor[regressor_key]
                grid = GridSearchCV(reg, parameters,scoring_fnc, cv=cvts)   
                grid = grid.fit(X, y)
                data_row=[
                    currency_pair,
                    regressor_key,
                    target,
                    dataset_key,
                    grid.best_score_,
                    features,
                    grid.best_estimator_
                ]
                data.append(data_row)
    result_cv=pd.DataFrame(data,columns=columns)
    result_cv.set_index(['Currency Pair','Regressor','Target','Dataset'],inplace=True)
    return result_cv

scores=fit_all(regressors,parameters_per_regressor,fs_results,set_of_datasets)

# %%
scores.sort_values('Score',ascending=False)
# Out:
#                                                                                     Score  \
# Currency Pair Regressor                 Target            Dataset
# btc_brl       LinearRegression          close_Target      log_close_series       0.975044
#                                                           log_close_series       0.975044
#                                                           log_close_series       0.975044
#                                                           clean_close_series     0.972352
#                                                           clean_close_series     0.972352
#                                                           clean_close_series     0.972352
#               Lasso                     close_Target      clean_close_series     0.972159
#                                                           clean_close_series     0.972159
#                                                           clean_close_series     0.972159
#               LinearRegression          close_Target      rescaled_close_series  0.971900
#                                                           rescaled_close_series  0.971900
#                                                           rescaled_close_series  0.971900
#                                                           log                    0.971689
#                                                           log                    0.971689
#                                                           log                    0.971689
#                                                           clean                  0.970912
#                                                           clean                  0.970912
#                                                           clean                  0.970912
#                                                           rescaled               0.970901
#                                                           rescaled               0.970901
#                                                           rescaled               0.970901
#               Lasso                     close_Target      clean                  0.970739
#                                                           clean                  0.970739
#                                                           clean                  0.970739
# btc_clp       LinearRegression          close_Target      log                    0.920515
#                                                           log                    0.920515
#                                                           log                    0.920515
#               Lasso                     close_Target      clean                  0.918330
#                                                           clean                  0.918330
#                                                           clean                  0.918330
# ...                                                                                   ...
# eth_pen       LinearRegression          log_return_Target log_divided            0.059449
#                                                           log_divided            0.059449
#                                                           log_divided            0.059449
# btc_brl       GradientBoostingRegressor close_Target      log                    0.054086
#                                                           log                    0.053284
#                                                           log                    0.050534
# eth_cop       LinearRegression          close_Target      log                   -0.024034
#                                                           log                   -0.024034
#                                                           log                   -0.024034
# eth_pen       LinearRegression          close_Target      log_close_series      -0.061723
#                                                           log_close_series      -0.061723
#                                                           log_close_series      -0.061723
#                                                           log                   -0.062209
#                                                           log                   -0.062209
#                                                           log                   -0.062209
# eth_cop       LinearRegression          log_return_Target log_divided           -0.081547
#                                                           log_divided           -0.081547
#                                                           log_divided           -0.081547
# btc_brl       DecisionTreeRegressor     close_Target      log_close_series      -0.151079
#                                                           log_close_series      -0.151079
#                                                           log_close_series      -0.151079
# btc_pen       LinearRegression          close_Target      rescaled              -0.250357
#                                                           rescaled              -0.250357
#                                                           rescaled              -0.250357
# btc_brl       DecisionTreeRegressor     close_Target      log                   -0.963372
#                                                           log                   -0.963372
#                                                           log                   -0.963372
# eth_cop       LinearRegression          close_Target      log_close_series      -9.466177
#                                                           log_close_series      -9.466177
#                                                           log_close_series      -9.466177
#
#                                                                                                                           Features  \
# Currency Pair Regressor                 Target            Dataset
# btc_brl       LinearRegression          close_Target      log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           clean_close_series                [close, Returns, log_return, log_MACD]
#                                                           clean_close_series                [close, Returns, log_return, log_MACD]
#                                                           clean_close_series                [close, Returns, log_return, log_MACD]
#               Lasso                     close_Target      clean_close_series                                               [close]
#                                                           clean_close_series                                               [close]
#                                                           clean_close_series                                               [close]
#               LinearRegression          close_Target      rescaled_close_series                      [close, log_return, log_MACD]
#                                                           rescaled_close_series                      [close, log_return, log_MACD]
#                                                           rescaled_close_series                      [close, log_return, log_MACD]
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           clean                             [close, Returns, log_return, log_MACD]
#                                                           clean                             [close, Returns, log_return, log_MACD]
#                                                           clean                             [close, Returns, log_return, log_MACD]
#                                                           rescaled                                   [close, log_return, log_MACD]
#                                                           rescaled                                   [close, log_return, log_MACD]
#                                                           rescaled                                   [close, log_return, log_MACD]
#               Lasso                     close_Target      clean                                                            [close]
#                                                           clean                                                            [close]
#                                                           clean                                                            [close]
# btc_clp       LinearRegression          close_Target      log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#               Lasso                     close_Target      clean                  [open, close, volume, Returns, log_return, Hei...
#                                                           clean                  [open, close, volume, Returns, log_return, Hei...
#                                                           clean                  [open, close, volume, Returns, log_return, Hei...
# ...                                                                                                                            ...
# eth_pen       LinearRegression          log_return_Target log_divided                                 [EWMA26, EWMA12, log_return]
#                                                           log_divided                                 [EWMA26, EWMA12, log_return]
#                                                           log_divided                                 [EWMA26, EWMA12, log_return]
# btc_brl       GradientBoostingRegressor close_Target      log                                          [close, EWMA26, log_return]
#                                                           log                                          [close, EWMA26, log_return]
#                                                           log                                          [close, EWMA26, log_return]
# eth_cop       LinearRegression          close_Target      log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log                    [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
# eth_pen       LinearRegression          close_Target      log_close_series                                                [EWMA12]
#                                                           log_close_series                                                [EWMA12]
#                                                           log_close_series                                                [EWMA12]
#                                                           log                                                             [EWMA12]
#                                                           log                                                             [EWMA12]
#                                                           log                                                             [EWMA12]
# eth_cop       LinearRegression          log_return_Target log_divided                                             [volume, EWMA26]
#                                                           log_divided                                             [volume, EWMA26]
#                                                           log_divided                                             [volume, EWMA26]
# btc_brl       DecisionTreeRegressor     close_Target      log_close_series                                                [EWMA12]
#                                                           log_close_series                                                [EWMA12]
#                                                           log_close_series                                                [EWMA12]
# btc_pen       LinearRegression          close_Target      rescaled                                          [EWMA26, EWMA12, MACD]
#                                                           rescaled                                          [EWMA26, EWMA12, MACD]
#                                                           rescaled                                          [EWMA26, EWMA12, MACD]
# btc_brl       DecisionTreeRegressor     close_Target      log                                                             [EWMA12]
#                                                           log                                                             [EWMA12]
#                                                           log                                                             [EWMA12]
# eth_cop       LinearRegression          close_Target      log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#                                                           log_close_series       [close, EWMA26, EWMA12, EWMA9, Returns, log_re...
#
#                                                                                                                      BestEstimator
# Currency Pair Regressor                 Target            Dataset
# btc_brl       LinearRegression          close_Target      log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean_close_series     LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean_close_series     LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean_close_series     LinearRegression(copy_X=True, fit_intercept=Tr...
#               Lasso                     close_Target      clean_close_series     Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
#                                                           clean_close_series     Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
#                                                           clean_close_series     Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
#               LinearRegression          close_Target      rescaled_close_series  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled_close_series  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled_close_series  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean                  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean                  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           clean                  LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
#               Lasso                     close_Target      clean                  Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
#                                                           clean                  Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
#                                                           clean                  Lasso(alpha=100, copy_X=True, fit_intercept=Tr...
# btc_clp       LinearRegression          close_Target      log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#               Lasso                     close_Target      clean                  Lasso(alpha=10000, copy_X=True, fit_intercept=...
#                                                           clean                  Lasso(alpha=10000, copy_X=True, fit_intercept=...
#                                                           clean                  Lasso(alpha=10000, copy_X=True, fit_intercept=...
# ...                                                                                                                            ...
# eth_pen       LinearRegression          log_return_Target log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
# btc_brl       GradientBoostingRegressor close_Target      log                    ([DecisionTreeRegressor(criterion='friedman_ms...
#                                                           log                    ([DecisionTreeRegressor(criterion='friedman_ms...
#                                                           log                    ([DecisionTreeRegressor(criterion='friedman_ms...
# eth_cop       LinearRegression          close_Target      log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
# eth_pen       LinearRegression          close_Target      log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log                    LinearRegression(copy_X=True, fit_intercept=Tr...
# eth_cop       LinearRegression          log_return_Target log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_divided            LinearRegression(copy_X=True, fit_intercept=Tr...
# btc_brl       DecisionTreeRegressor     close_Target      log_close_series       DecisionTreeRegressor(criterion='mse', max_dep...
#                                                           log_close_series       DecisionTreeRegressor(criterion='mse', max_dep...
#                                                           log_close_series       DecisionTreeRegressor(criterion='mse', max_dep...
# btc_pen       LinearRegression          close_Target      rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           rescaled               LinearRegression(copy_X=True, fit_intercept=Tr...
# btc_brl       DecisionTreeRegressor     close_Target      log                    DecisionTreeRegressor(criterion='mse', max_dep...
#                                                           log                    DecisionTreeRegressor(criterion='mse', max_dep...
#                                                           log                    DecisionTreeRegressor(criterion='mse', max_dep...
# eth_cop       LinearRegression          close_Target      log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#                                                           log_close_series       LinearRegression(copy_X=True, fit_intercept=Tr...
#
# [159 rows x 3 columns]
